# %%
# !git clone https://github.com/swz30/Restormer.git
# %cd Restormer

# !pip install torch torchvision torchaudio
# !pip uninstall -y basicsr
# !pip install basicsr==1.4.2
# Out:
# Cloning into 'Restormer'...
# remote: Enumerating objects: 312, done.
# remote: Counting objects: 100% (123/123), done.
# remote: Compressing objects: 100% (47/47), done.
# remote: Total 312 (delta 78), reused 76 (delta 76), pack-reused 189 (from 1)
# Receiving objects: 100% (312/312), 1.55 MiB | 23.65 MiB/s, done.
# Resolving deltas: 100% (131/131), done.
# /content/Restormer
# ...
# WARNING: Skipping basicsr as it is not installed.
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 172.5/172.5 kB 6.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.8/46.8 kB 4.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 333.1/333.1 kB 21.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 85.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 256.2/256.2 kB 29.6 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
file_path = "/usr/local/lib/python3.12/dist-packages/basicsr/data/degradations.py"

with open(file_path, "r") as f:
    content = f.read()

content = content.replace(
    "from torchvision.transforms.functional_tensor import rgb_to_grayscale",
    "from torchvision.transforms.functional import rgb_to_grayscale"
)

with open(file_path, "w") as f:
    f.write(content)

print("Patched successfully!")
# Out:
# Patched successfully!

# %%
import os
size = os.path.getsize("/content/drive/MyDrive/MLSP_Restormer/blur_5.5k.zip")
print(f"File size: {size / 1e6:.1f} MB")
# Out:
# File size: 851.6 MB

# %%
import zipfile

zip_path = "/content/drive/MyDrive/MLSP_Restormer/blur_5.5k.zip"
extract_path = "/content/MLSP_sharp"

# First, peek inside to see folder structure
with zipfile.ZipFile(zip_path, 'r') as z:
    all_files = z.namelist()
    # Print top level folders
    folders = set(f.split('/')[0] for f in all_files)
    print("Folders in zip:", folders)
# Out:
# Folders in zip: {'blur_5k'}

# %%
import shutil
shutil.copy("/content/drive/MyDrive/MLSP_Restormer/blur_5.5k.zip", "/content/dataset.zip")
print("Copied to Colab storage for faster extracting")
# Out:
# Copied to Colab storage for faster extracting

# %%
import zipfile

zip_path = "/content/drive/MyDrive/MLSP_Restormer/blur_5.5k.zip"
extract_path = "/content/"

with zipfile.ZipFile(zip_path, 'r') as z:
    z.extractall(extract_path)

print("✅ Extracted!")
# Out:
# ✅ Extracted!

# %%
import os
size = os.path.getsize("/content/drive/MyDrive/MLSP_Restormer/sharp_5.5k.zip")
print(f"File size: {size / 1e6:.1f} MB")
# Out:
# File size: 414.9 MB

# %%
import zipfile

zip_path = "/content/drive/MyDrive/MLSP_Restormer/sharp_5.5k.zip"
extract_path = "/content/MLSP_sharp"

# First, peek inside to see folder structure
with zipfile.ZipFile(zip_path, 'r') as z:
    all_files = z.namelist()
    # Print top level folders
    folders = set(f.split('/')[0] for f in all_files)
    print("Folders in zip:", folders)

import shutil
shutil.copy("/content/drive/MyDrive/MLSP_Restormer/sharp_5.5k.zip", "/content/dataset.zip")
print("Copied to Colab storage for faster extracting")

import zipfile

zip_path = "/content/drive/MyDrive/MLSP_Restormer/sharp_5.5k.zip"
extract_path = "/content/"

with zipfile.ZipFile(zip_path, 'r') as z:
    z.extractall(extract_path)

print("✅ Extracted!")
# Out:
# Folders in zip: {'sharp_5.5k'}
# Copied to Colab storage for faster extracting
# ✅ Extracted!

# %%
import zipfile

zip_path = "/content/drive/MyDrive/MLSP_Restormer/blur_100_test.zip"
extract_path = "/content/MLSP_TEST_B"

# First, peek inside to see folder structure
with zipfile.ZipFile(zip_path, 'r') as z:
    all_files = z.namelist()
    # Print top level folders
    folders = set(f.split('/')[0] for f in all_files)
    print("Folders in zip:", folders)

import shutil
shutil.copy("/content/drive/MyDrive/MLSP_Restormer/blur_100_test.zip", "/content/dataset.zip")
print("Copied to Colab storage for faster extracting")

import zipfile

zip_path = "/content/drive/MyDrive/MLSP_Restormer/blur_100_test.zip"
extract_path = "/content/"

with zipfile.ZipFile(zip_path, 'r') as z:
    z.extractall(extract_path)

print("✅ Extracted!")
# Out:
# Folders in zip: {'blur_100_test'}
# Copied to Colab storage for faster extracting
# ✅ Extracted!

# %%
import zipfile

zip_path = "/content/drive/MyDrive/MLSP_Restormer/sharp_100_test.zip"
extract_path = "/content/MLSP_TEST_S"

# First, peek inside to see folder structure
with zipfile.ZipFile(zip_path, 'r') as z:
    all_files = z.namelist()
    # Print top level folders
    folders = set(f.split('/')[0] for f in all_files)
    print("Folders in zip:", folders)

import shutil
shutil.copy("/content/drive/MyDrive/MLSP_Restormer/sharp_100_test.zip", "/content/dataset.zip")
print("Copied to Colab storage for faster extracting")

import zipfile

zip_path = "/content/drive/MyDrive/MLSP_Restormer/sharp_100_test.zip"
extract_path = "/content/"

with zipfile.ZipFile(zip_path, 'r') as z:
    z.extractall(extract_path)

print("✅ Extracted!")
# Out:
# Folders in zip: {'sharp_100_test'}
# Copied to Colab storage for faster extracting
# ✅ Extracted!

# %%
from PIL import Image
import os

TARGET_SIZE = (296, 296)  # 300 -> 296 (nearest multiple of 8)

folders = [
    '/content/sharp_5.5k',
    '/content/blur_5k',
    '/content/sharp_100_test',
    '/content/blur_100_test'
]

for folder in folders:
    files = os.listdir(folder)
    for fname in files:
        if fname.lower().endswith(('.png', '.jpg', '.jpeg')):
            path = os.path.join(folder, fname)
            img = Image.open(path).convert('RGB')
            if img.size != TARGET_SIZE:
                img = img.resize(TARGET_SIZE, Image.LANCZOS)
                img.save(path)
    print(f"✅ {folder}: {len(files)} images resized to {TARGET_SIZE}")

print("\n✅ All folders done!")
# Out:
# ✅ /content/sharp_5.5k: 5501 images resized to (296, 296)
# ✅ /content/blur_5k: 5501 images resized to (296, 296)
# ✅ /content/sharp_100_test: 100 images resized to (296, 296)
# ✅ /content/blur_100_test: 100 images resized to (296, 296)
#
# ✅ All folders done!

# %%
# %cd /content/Restormer
# Out:
# /content/Restormer

# %%
# !touch train.yml

# %%
import os

folder = '/content/sharp_5.5k'

for f in os.listdir(folder):
    if f.endswith('_orig.png'):
        new_name = f.replace('_orig', '_blur')
        os.rename(os.path.join(folder, f), os.path.join(folder, new_name))

print("Renamed target files!")
# Out:
# Renamed target files!

# %%
import os

folder = '/content/sharp_100_test'

for f in os.listdir(folder):
    if f.endswith('_orig.png'):
        new_name = f.replace('_orig', '_blur')
        os.rename(os.path.join(folder, f), os.path.join(folder, new_name))

print("Renamed target files in test!")
# Out:
# Renamed target files in test!

# %%
import os

inp = sorted(os.listdir('/content/blur_5k'))
tar = sorted(os.listdir('/content/sharp_5.5k'))

print(inp[:5])
print(tar[:5])
# Out:
# ['0000000_blur.png', '0000001_blur.png', '0000002_blur.png', '0000003_blur.png', '0000004_blur.png']
# ['0000000_blur.png', '0000001_blur.png', '0000002_blur.png', '0000003_blur.png', '0000004_blur.png']

# %%
# !pip uninstall -y basicsr
# Out:
# WARNING: Skipping basicsr as it is not installed.

# %%
import sys
sys.path.insert(0, "/content/Restormer")

# %%
import random
import numpy as np
import torch

seed = 42
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)
print(f"✅ Random seed set to {seed}")
# Out:
# ✅ Random seed set to 42

# %%
import os
os.makedirs("/content/Restormer/experiments/Restormer_Test", exist_ok=True)
print("✅ Directory created!")
# Out:
# ✅ Directory created!

# %%
import shutil, os

src = "/content/drive/MyDrive/MLSP_Restormer/checkpoints"
dst = "/content/Restormer/experiments/Restormer_Test"

os.makedirs(dst, exist_ok=True)
shutil.copytree(src, dst, dirs_exist_ok=True)
print("✅ Checkpoints copied to expected location!")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_2980/1004925476.py in <cell line: 0>()
#       5
#       6 os.makedirs(dst, exist_ok=True)
# ----> 7 shutil.copytree(src, dst, dirs_exist_ok=True)
#       8 print("✅ Checkpoints copied to expected location!")
#
# /usr/lib/python3.12/shutil.py in copytree(src, dst, symlinks, ignore, copy_function, ignore_dangling_symlinks, dirs_exist_ok)
#     598     with os.scandir(src) as itr:
#     599         entries = list(itr)
# --> 600     return _copytree(entries=entries, src=src, dst=dst, symlinks=symlinks,
#     601                      ignore=ignore, copy_function=copy_function,
#     602                      ignore_dangling_symlinks=ignore_dangling_symlinks,
#
# /usr/lib/python3.12/shutil.py in _copytree(entries, src, dst, symlinks, ignore, copy_function, ignore_dangling_symlinks, dirs_exist_ok)
# ...

# %%
import os, glob, re, subprocess, threading, time, shutil

# %cd /content/Restormer

# ── Auto-backup to Drive every 10 mins ─────────────────────────────
def backup_loop():
    while True:
        time.sleep(600)
        src = "/content/Restormer/experiments/Restormer_Test"
        dst = "/content/drive/MyDrive/MLSP_Restormer/checkpoints"
        os.makedirs(dst, exist_ok=True)
        shutil.copytree(src, dst, dirs_exist_ok=True)
        print("✅ Auto-backup to Drive done")

t = threading.Thread(target=backup_loop, daemon=True)
t.start()

# ── Find latest .state checkpoint ──────────────────────────────────
states_dir = "/content/drive/MyDrive/MLSP_Restormer/checkpoints/training_states"
resume_path = None

if os.path.exists(states_dir):
    states = sorted(
        glob.glob(f"{states_dir}/*.state"),
        key=lambda x: int(os.path.basename(x).split(".")[0])
    )
    if states:
        resume_path = states[-1]
        print(f"Resuming from: {resume_path}")
    else:
        print("Starting fresh — no checkpoints found")
else:
    print("Starting fresh — checkpoint dir doesn't exist yet")

# ── Patch resume_state in train.yml ────────────────────────────────
with open("train.yml", "r") as f:
    yml = f.read()

if resume_path:
    yml = re.sub(r"resume_state:.*", f"resume_state: {resume_path}", yml)
else:
    yml = re.sub(r"resume_state:.*", "resume_state: ~", yml)

with open("train.yml", "w") as f:
    f.write(yml)

# ── Train ───────────────────────────────────────────────────────────
# !python -m basicsr.train -opt train.yml
# Out:
# /content/Restormer
# Resuming from: /content/drive/MyDrive/MLSP_Restormer/checkpoints/training_states/25000.state
# Disable distributed.
# 2026-04-25 10:44:18,167 INFO:
#                 ____                _       _____  ____
#                / __ ) ____ _ _____ (_)_____/ ___/ / __ \
#               / __  |/ __ `// ___// // ___/\__ \ / /_/ /
#              / /_/ // /_/ /(__  )/ // /__ ___/ // _, _/
#             /_____/ \__,_//____//_/ \___//____//_/ |_|
#      ______                   __   __                 __      __
#     / ____/____   ____   ____/ /  / /   __  __ _____ / /__   / /
#    / / __ / __ \ / __ \ / __  /  / /   / / / // ___// //_/  / /
#   / /_/ // /_/ // /_/ // /_/ /  / /___/ /_/ // /__ / /<    /_/
#   \____/ \____/ \____/ \____/  /_____/\____/ \___//_/|_|  (_)
#
# Version Information:
# 	BasicSR: 1.2.0+10018c6
# 	PyTorch: 2.10.0+cu128
# 	TorchVision: 0.25.0+cu128
# 2026-04-25 10:44:18,167 INFO:
#   name: Restormer_Test
#   model_type: ImageCleanModel
#   scale: 1
# ...
